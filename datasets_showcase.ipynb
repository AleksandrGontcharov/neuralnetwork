# %%
from neuralnetwork.datasets import blobs, nregion, circle

# %% [markdown]
# # 1-D Three-Region Dataset

# %%
X_train, Y_train2, X_val, Y_val, C = nregion.load_data(regions=2)
nregion.graph(X_train, Y_train2, size = 10)
nregion.graph(X_val, Y_val, size = 10)

# %% [markdown]
# # 1-D Random Dataset

# %%
X_train, Y_train, X_val, Y_val = nregion.load_random_data(points=300)
nregion.graph(X_train, Y_train, size = 10)
nregion.graph(X_val, Y_val, size = 10)

# %% [markdown]
# # 1-D Random Regions

# %%
X_train, Y_train, X_val, Y_val, C, R = nregion.load_random_regions(regions=6, validation = 0.20, points=50)
nregion.graph(X_train, Y_train, size = 10, padding=5)
nregion.graph(X_val, Y_val, size = 10, padding=5)

# %%
nregion.graph(X, Y, padding = 10, size = 1)

# %%
import numpy as np
regions = 6
points = 50
C = list(np.sort(np.random.rand(regions)*10))
# Extract radii
R = [min((C[index]-C[index-1])/2,(C[index+1]-C[index])/2) for index in range(1,len(C)-1)]
R.insert(0,(C[1]-C[0])/2)
R.append((C[-1]-C[-2])/2)
# Initialize X and Y
X = np.random.randn(0)
Y = np.random.randn(0)
for index in range(len(C)):
    X = np.append(X,np.random.rand(points)*R[index]+C[index]-0.5)
    Y = np.append(Y,np.zeros(points) +  (index % 2))
X = X.reshape(X.shape[0],1)

# %%
C
# Out:
# [1.066435078392819,
#  2.9558114321629834,
#  3.2018457298417835,
#  4.696411989662587,
#  6.181107164373001,
#  6.47805077242217]

# %%
R
# Out:
# [0.9446881768850822,
#  0.12301714883940007,
#  0.12301714883940007,
#  0.7423475873552072,
#  0.14847180402458449,
#  0.14847180402458449]

# %%
nregion.graph(X, Y, padding = 10, size = 1)

# %%
np.random.rand(points)*2+100-0.5

# %%
R = np.zeros_like(C)

# %%
print(radii)

# %%
X_train, Y_train, X_val, Y_val = nregion.load_random_regions(points=300)
nregion.graph(X_train, Y_train, size = 10)
nregion.graph(X_val, Y_val, size = 10)

# %% [markdown]
# # 2D Blobs Dataset

# %%
X, Y = blobs.load_data(size=100)
blobs.graph(X,Y)

# %% [markdown]
# # 2D Circles Dataset

# %%
X, Y = circle.load_data(size=100, factor = 4)
circle.graph(X,Y)
