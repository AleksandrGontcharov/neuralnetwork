# %%
from neuralnetwork.datasets import blobs, nregion

# %% [markdown]
# # 2D Blobs Dataset

# %%
X, Y = blobs.load_data(size=100)
blobs.graph(X,Y)

# %% [markdown]
# # 1-D Three-Region Dataset

# %%
X, Y = nregion.load_data()
nregion.graph(X,Y)
