# %%
from neuralnetwork.datasets import blobs, nregion, circle

# %% [markdown]
# # 2D Blobs Dataset

# %%
X, Y = blobs.load_data(size=100)
blobs.graph(X,Y)

# %% [markdown]
# # 1-D Three-Region Dataset

# %%
X_train, Y_train, X_val, Y_val, C = nregion.load_data(regions=3)
nregion.graph(X_train, Y_train)
nregion.graph(X_val, Y_val)

# %% [markdown]
# # 2D Circles Dataset

# %%
X, Y = circle.load_data(size=100, factor = 4)
circle.graph(X,Y)

# %%
import numpy as np
regions = 3
validation = 0.20
# Initialize list of centers



C = []
X = np.random.rand(50)
Y = np.zeros(50)
for n in range(1,regions):
    X = np.append(X, np.random.rand(50) + 2*n)
    if n % 2 == 1:
        C.append(0.5 + 2*n)
    Y = np.append(Y, np.zeros(50) + (n % 2))
X = X.reshape(X.shape[0],1)
# Split into training and validation sets
training_samples = int(len(X)*(1-validation))
validation_samples = len(X) - training_samples

indices = np.arange(X.shape[0])
np.random.shuffle(indices)
X = X[indices]
Y = Y[indices]
X_train = X[:training_samples]
Y_train = Y[:training_samples]

X_val = X[training_samples: training_samples + validation_samples]
Y_val = X[training_samples: training_samples + validation_samples]

# %%
len(X_val)

# %%
validation_samples
