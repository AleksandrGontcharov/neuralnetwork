# %%
from neuralnetwork.datasets import blobs, nregion, circle

# %% [markdown]
# # 1-D Three-Region Dataset

# %%
X_train, Y_train, X_val, Y_val, C = nregion.load_data(regions=10)
nregion.graph(X_train, Y_train, size = 30)
nregion.graph(X_val, Y_val, size = 30)

# %% [markdown]
# # 1-D Random Dataset

# %%
X_train, Y_train, X_val, Y_val = nregion.load_random_data(points=100)
nregion.graph(X_train, Y_train, size = 10)
nregion.graph(X_val, Y_val, size = 10)

# %% [markdown]
# # 1-D Random Regions

# %%
X_train, Y_train, X_val, Y_val, C, R = nregion.load_random_regions(regions=9, validation = 0.20, points=50)
nregion.graph(X_train, Y_train, size = 10, padding=10)
nregion.graph(X_val, Y_val, size = 10, padding=10)

# %%
C

# %%
C[1:][::2]

# %%
C_final = [C[2*i] for i in range(int(C)/2)]

# %%
R

# %% [markdown]
# # 2D Blobs Dataset

# %%
X, Y = blobs.load_data(size=100)
blobs.graph(X,Y)

# %% [markdown]
# # 2D Circles Dataset

# %%
X, Y = circle.load_data(size=100, factor = 4)
circle.graph(X,Y)
